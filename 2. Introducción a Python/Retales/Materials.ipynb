# %% [markdown]
# # Materials Notebook
# This document contains links to the various learning materials used throughout the program. These are organized by the python library highlighted in each notebook.
#
# ## Numpy
# [Intro to Numpy Notebook](./weeks/week1/day1/intro_numpy.ipynb)
#
# ## Pandas
# [Intro to Pandas Notebook](./weeks/week1/day1/intro_pandas.ipynb)<br>
# [Advanced Data Manipulation with Pandas](./weeks/week1/day2/advanced_pandas.ipynb)<br>
# [Data Cleaning with Pandas Notebook](./weeks/week1/day3/data_cleaning_pandas.ipynb)
#
# ## Matplotlib
# [Intro to Matplotlib Notebook](./weeks/week1/day2/intro_matplotlib.ipynb)
#
# ## Seaborn
# [Intro to Seaborn Notebook](./weeks/week1/day2/intro_seaborn.ipynb)
#
# ## PyDrive
# [Intro to PyDrive](./weeks/week1/day3/intro_pydrive.ipynb)
#
# ## Scikit-Learn
# [Linear Regression with Sklearn](./weeks/week1/day3/linear_regression_sklearn.ipynb)<br>
# [Linear Regression Guided Example](./weeks/week1/day5/linear_regression_sklearn_practice.ipynb)<br>
# [Logistic Regression with Sklearn](./weeks/week1/day4/logistic_regression_sklearn.ipynb)<br>
# [Logistic Regression Guided Example](./weeks/week1/day5/logistic_regression_sklearn_practice.ipynb)<br>
# [Random Forest Guided Example](./weeks/week2/day2/Random_Forests/random_forest_sklearn.ipynb)<br>
# [Gradient Boosting Guided Example](./weeks/week2/day2/Gradient_Boosting/gradient_boosting_sklearn.ipynb)<br>
# [Intro to PCA](./weeks/week2/day3/Dimensionality_Reduction_PCA/pca_sklearn.ipynb)<br>
# [Class Imbalance Pitfall: 99% Accuracy Example](./weeks/week2/day3/class_imbalance.ipynb)<br>
# [](./weeks/week3/Time_Series/forecasting_linear_regression_sklearn.ipynb)
#
# ## Statsmodels
# [Intro to Time Series & ARIMA](./weeks/week3/Time_Series/intro_time_series.ipynb)
#
#
# ## Optimization
# [Optimization Theory](./weeks//week2/day1/optimization/optimization_overview.ipynb)<br>
#
# ## Hyperopt
# [Hyperopt Guided Example](./weeks/week2/day1/optimization/optimization_hyperopt.ipynb)
#
# ## Pydotplus
# [Simple Decision Tree Models](./weeks/week2/day2/Random_Forests/decision_tree_graphvis_pydotplus.ipynb)
#
# ## XGBoost
# [Gradient Boosted Trees Example](../../week2/day2/Gradient_Boosting/gradient_boosting_xgboost.ipynb)
#
# ## Scipy
# [Sparse Data Structures in SciPy](./weeks/week2/day3/Sparse_Data/sparse_data_scipy.ipynb)
#
# ## Agile Methodology
# [Introduction to Agile](./weeks/week2/day4/intro_to_agile.pdf)
#
# ## Unix/Linux Command Line
# [Intro to the Command Line](./weeks/week3/Linux_Commands/command_line.ipynb)
#
# ## Facebook Prophet
# [forecasting_facebook_prophet.ipynb](./weeks/week3/Time_Series/forecasting_facebook_prophet.ipynb)
#
# ## Deep Learning
# [Intro to Deep Learning](./weeks/week4/Deep_Learning_/deep_learning_keras_intro/intro_deep_learning_keras.ipynb)
#
# ## Keras
# [Intro to Keras](./weeks/week4/Deep_Learning_/intro_keras.ipynb)<br>
# [Customer Churn Example with Keras](./weeks/week4/Deep_Learning_/customer_churn_keras.ipynb)<br>
# [Generate Text Keras](./weeks/week4/Deep_Learning_/generate_text_keras.ipynb)
#
# ## NLTK
# [Intro to NLP with NLTK](./weeks/week4/Deep_Learning_/intro_nlp_nltk.ipynb)
#
# ## Gensim
# [Word2Vec with Gensim](./weeks/week4/Deep_Learning_/intro_word2vec_gensim.ipynb)
#
# ## Vadersentiment
# [Intro to Sentiment Analysis with Vadersentiment](./weeks/week5/Sentiment_Analysis/intro_sentiment_analysis_vadersentiment.ipynb)
#
# ## FastText
# [Topic Modeling with FastText](./weeks/week5/Topic_modeling/topic_modeling_fasttext.ipynb)
#
# ## pyLDAvis
# [Intro to Topic Modeling with pyLDAvis](./weeks/week5/Topic_modeling/intro_topic_modeling_LDA_pyLDAvis.ipynb)
#
# ## Surprise
# [Recommendation System with Surprise](./weeks/week6/Rec_system/recommendation_system_surprise.ipynb)
